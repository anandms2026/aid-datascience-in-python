# %%
def proportion_of_education():
    # your code goes here
    #DUC1 – education of the mother <12 years 12 years
    #>12 years, not a college graduate College graduate
    # YOUR CODE HERE
    raise NotImplementedError()
