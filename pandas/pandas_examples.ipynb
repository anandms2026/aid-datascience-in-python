# %%
 # !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 46.2 MB/s  0:00:0027.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 85.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]━━━━━━━━━━━ 2/3 [pandas]
# ...

# %%
import pandas as pd
students=["Alice","Jack","Molly"]
print(students)
# Out:
# ['Alice', 'Jack', 'Molly']

# %%
pd.Series(students)
# Out:
# 0    Alice
# 1     Jack
# 2    Molly
# dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
students_score={"Alice":"Physics",
                "Jack":"Chemistry",
                "Molly":"English"}
s= pd.Series(students_score)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
s.index
# Out:
# Index(['Alice', 'Jack', 'Molly'], dtype='object')
