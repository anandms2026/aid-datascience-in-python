# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
obj3['California']
# Out:
# np.True_

# %%
import math
math.isnan(obj2['California'])
# Out:
# True

# %%
obj2['California'] == None
# Out:
# False

# %%
import pandas as pd
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)

# %%
S.iloc[0:2]
# Out:
# 1    Alice
# 2      Bob
# dtype: object

# %%
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
import pandas as pd
records1 = pd.Series({"Name":"Alice","Class":"Physics","Score":85})
records2 = pd.Series({"Name":"Jack","Class":"Chemistry","Score":82})
records3 = pd.Series({"Name":"Molly","Class":"Biology","Score":90})
df = pd.DataFrame([records1,records2,records3],index=["school1","school2","school1"])
df.head()
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
df.rename(mapper=lambda x:x.upper(),axis=1,inplace=True)
df.head()
# Out:
#           NAME      CLASS  SCORE
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
df1 = df.rename(mapper=lambda x: x.upper(),axis='columns')
df1.head()
# Out:
#           NAME      CLASS  SCORE
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
df2= df.rename(mapper=lambda x: x.upper(),axis=1)
df2.head()
# Out:
#           NAME      CLASS  SCORE
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
df3 = df.rename(mapper=lambda x:x.upper(),axis=1)
df3.head()
# Out:
#           NAME      CLASS  SCORE
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
import pandas as pd
records1 = pd.Series({"gre score":"337","toefl":"118"})
records2 = pd.Series({"gre score":"324","toefl":"107"})
records3 = pd.Series({"gre score":"316","toefl":"104"})
records4 = pd.Series({"gre score":"322","toefl":"110"})
records5 = pd.Series({"gre score":"314","toefl":"103"})

df = pd.DataFrame([records1,records2,records3],index=["school1","school2","school1"])
df.head()
# Out:
#         gre score toefl
# school1       337   118
# school2       324   107
# school1       316   104

# %%
df['toefl'] = pd.to_numeric(df['toefl'], errors='coerce')
df[df['toefl'] > 105]
df.head()
# Out:
#         gre score  toefl
# school1       337    118
# school2       324    107
# school1       316    104

# %%
import pandas as pd
records1 = pd.Series({"one":"1","two":"1","three":"2","four":"3"})
records2 = pd.Series({"one":"4","5":"2","three":"6","four":"7"})
records3 = pd.Series({"one":"8","two":"9","three":"10","four":"11"})
records4 = pd.Series({"one":"12","two":"13","three":"14","four":"4"})

df = pd.DataFrame([records1,records2,records3,records4],index=["Ohio","Colorado","Utah","NYC"])
df.head()
# Out:
#          one  two three four    5
# Ohio       1    1     2    3  NaN
# Colorado   4  NaN     6    7    2
# Utah       8    9    10   11  NaN
# NYC       12   13    14    4  NaN

# %%
df.drop('one',axis=1)
df.head()
# Out:
#          one  two three four    5
# Ohio       1    1     2    3  NaN
# Colorado   4  NaN     6    7    2
# Utah       8    9    10   11  NaN
# NYC       12   13    14    4  NaN

# %%
df.drop(["Utah","Colorado"])
# Out:
#      one two three four    5
# Ohio   1   1     2    3  NaN
# NYC   12  13    14    4  NaN

# %%
df.drop('two')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.drop('two')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})
s2[1]
# Out:
# /var/folders/y9/kswx7vmd4qq__6lg8px9jl3r0000gn/T/ipykernel_37365/2409800886.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2[1]
# np.int64(2)

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
s2.iloc[1]
# Out:
# np.int64(2)

# %%
s2.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ...

# %%
import pandas as pd

# %%
records1 = pd.Series({"gre score":"337","toefl":"118"})
records2 = pd.Series({"gre score":"324","toefl":"107"})
records3 = pd.Series({"gre score":"316","toefl":"104"})
records4 = pd.Series({"gre score":"322","toefl":"110"})
records5 = pd.Series({"gre score":"314","toefl":"103"})

df = pd.DataFrame([records1,records2,records3,records4,records5],index=["1","2","3","4","5"])
df.head()
df.where(df['toefl']>105)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 9
#       7 df = pd.DataFrame([records1,records2,records3,records4,records5],index=["1","2","3","4","5"])
#       8 df.head()
# ----> 9 df.where(df['toefl']>105)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# ...

# %%
df['toefl'] = pd.to_numeric(df['toefl'], errors='coerce')
df[(df['toefl'] > 105) & (df['toefl'] < 115)]
# Out:
#   gre score  toefl
# 2       324    107
# 4       322    110

# %%
df['toefl'] = pd.to_numeric(df['toefl'], errors='coerce')
df[(df['toefl'] > 105) & (df['toefl'] < 115)]
# Out:
#   gre score  toefl
# 2       324    107
# 4       322    110

# %%
df['toefl'] = pd.to_numeric(df['toefl'], errors='coerce')
df[(df['toefl']).gt(105) & (df['toefl'].lt(115))]
# Out:
#   gre score  toefl
# 2       324    107
# 4       322    110
