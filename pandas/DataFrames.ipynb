# %%
import pandas as pd
records1 = pd.Series({"Name":"Alice","Class":"Physics","Score":85})
records2 = pd.Series({"Name":"Jack","Class":"Chemistry","Score":82})
records3 = pd.Series({"Name":"Molly","Class":"Biology","Score":90})
df = pd.DataFrame([records1,records2,records3],index=["school1","school2","school1"])
df.head()
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Molly    Biology     90

# %%
students = [{"Name":"Alice","Class":"Physics","Score":85},
                     {"Name":"Jack","Class":"Chemistry","Score":82},
                    {"Name":"Helen","Class":"Biology","Score":90}
                    ]
df = pd.DataFrame(students, index=["school1","school2","school1"])
df.head()
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
df.loc["school2"]
# Out:
# Name          Jack
# Class    Chemistry
# Score           82
# Name: school2, dtype: object

# %%
copy_df = df.copy()
copy_df.drop("Name", inplace=True,axis=1)
copy_df
# Out:
#              Class  Score
# school1    Physics     85
# school2  Chemistry     82
# school1    Biology     90

# %%
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
copy_df
# Out:
#              Class  Score
# school1    Physics     85
# school2  Chemistry     82
# school1    Biology     90

# %%
import pandas as pd
df=pd.read_csv('dataset/student.csv')
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df=pd.read_csv('dataset/student.csv',index_col=0)
df.head()
# Out:
#           name  class  mark  gender
# id
# 1     John Deo   Four    75  female
# 2     Max Ruin  Three    85    male
# 3       Arnold  Three    55    male
# 4   Krish Star   Four    60  female
# 5    John Mike   Four    60  female

# %%
new_df = df.rename(columns={'mark':"StudentMarks","gender":"StudentGender"})
new_df.head()
# Out:
#           name  class  StudentMarks StudentGender
# id
# 1     John Deo   Four            75        female
# 2     Max Ruin  Three            85          male
# 3       Arnold  Three            55          male
# 4   Krish Star   Four            60        female
# 5    John Mike   Four            60        female

# %%
new_df.columns
# Out:
# Index(['name', 'class', 'StudentMarks', 'StudentGender'], dtype='object')

# %%
admit_nextgrade=new_df["StudentMarks"]>70
admit_nextgrade
# Out:
# id
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35     True
# Name: StudentMarks, dtype: bool

# %%
df.where(admit_nextgrade).head()
# Out:
#         name  class  mark  gender
# id
# 1   John Deo   Four  75.0  female
# 2   Max Ruin  Three  85.0    male
# 3        NaN    NaN   NaN     NaN
# 4        NaN    NaN   NaN     NaN
# 5        NaN    NaN   NaN     NaN

# %%
df.where(admit_nextgrade).dropna().head()
# Out:
#            name  class  mark  gender
# id
# 1      John Deo   Four  75.0  female
# 2      Max Ruin  Three  85.0    male
# 7   My John Rob  Fifth  78.0    male
# 8        Asruid   Five  85.0    male
# 9       Tes Qry    Six  78.0    male

# %%
import pandas as pd
import math
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
# obj3['California']
# math.isnan(obj2['California'])
obj2['California'] == None
# x = obj2['California']
# obj2['California'] != x
# Out:
# False

# %%
import pandas as pd
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
df.head()
# Out:
#           name  class  mark  gender
# id
# 1     John Deo   Four    75  female
# 2     Max Ruin  Three    85    male
# 3       Arnold  Three    55    male
# 4   Krish Star   Four    60  female
# 5    John Mike   Four    60  female

# %%
df=df.rename(mapper=lambda x:x.upper(),axis='columns')

# %%
df.head()
# Out:
#           NAME  CLASS  MARK  GENDER
# id
# 1     John Deo   Four    75  female
# 2     Max Ruin  Three    85    male
# 3       Arnold  Three    55    male
# 4   Krish Star   Four    60  female
# 5    John Mike   Four    60  female

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})
s2[1]
# Out:
# /var/folders/y9/kswx7vmd4qq__6lg8px9jl3r0000gn/T/ipykernel_33997/2409800886.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2[1]
# np.int64(2)

# %%
s2.iloc[1]
# Out:
# np.int64(2)

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
s2.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s2.loc[1]
# ...
