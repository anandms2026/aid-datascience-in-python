# %%
import unittest
import regex as re
class Email_RegexTest(unittest.TestCase):
    def test_emailregex(self):
        str = "emailid: funk@example.com"
        expected= "email:"
        self.assertEqual(re.regex_email(str),expected)
    test_emailregex
